# %%
# %pip install deeplake --user
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\yashk\appdata\roaming\python\python311\site-packages\pyiwn-0.0.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\pyiwn-0.0.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# evaluate 0.4.1 requires datasets>=2.0.0, but you have datasets 1.18.3 which is incompatible.
#   Using cached deeplake-3.9.2-py3-none-any.whl
# ...
#   Using cached pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# ...

# %%
from datasets import load_dataset

train_dataset = load_dataset('librispeech_asr', 'clean', split='train.100', streaming=True)
for i, example in enumerate(train_dataset):
        print(f"Example {i}:")
        print(example)
        print("\n")

# %%
import deeplake
ds = deeplake.load("hub://activeloop/timit-train")
test = deeplake.load("hub://activeloop/timit-test")
# Out:
# |
# Opening dataset in read-only mode as you don't have write permissions.
# |
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/timit-train
# -
# hub://activeloop/timit-train loaded successfully.
# -
# Opening dataset in read-only mode as you don't have write permissions.
# \
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/timit-test
# |
# hub://activeloop/timit-test loaded successfully.
# Tensor(key='audios')

# %%
ds['audios'][0]
# Out:
# Tensor(key='audios', index=Index([0]))

# %%
dataloader = ds.pytorch(num_workers=0, batch_size=4, shuffle=False)

# %%
audios, texts, dialects = None, None, None
for audio, text, dialect in dataloader:
    audios = audio
    texts = text
    dialects = dialect

    print(text[0])

print(texts[0])
# Out:
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[0]
#   warn(
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[1]
#   warn(
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[2]
#   warn(
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[3]
#   warn(
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[4]
#   warn(
# C:\Users\yashk\AppData\Roaming\Python\Python311\site-packages\deeplake\core\io.py:413: UserWarning: Skipping corrupt wav sample at dataset.audios[5]
#   warn(
# ...

# %%
import soundfile as sf
import torch
from datasets import load_dataset
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

dataset = load_dataset("timit_asr", split="test").shuffle().select(range(10))

dataset
# Out:
# ---------------------------------------------------------------------------
# ManualDownloadError                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 from datasets import load_dataset
#       4 from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
# ----> 6 dataset = load_dataset("timit_asr", split="test").shuffle().select(range(10))
#       8 dataset
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\load.py:2152, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2149 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2151 # Download and prepare data
# -> 2152 builder_instance.download_and_prepare(
#    2153     download_config=download_config,
#    2154     download_mode=download_mode,
# ...
